# %%
# In the basic of python we discussed about the (print function , variables , data types , input function & operators )

# 30 Python practice questions from the following
# topics: print function, variables, data types, input function, and operators,
# Divide the questions into 3 levels: 10 Basic, 10 Intermediate, and 10 Hard.

# %%
# Basic Level (Foundations – 10 Questions)

# %%
# Write a program that prints your name and age on two separate lines.
print("Name : Tahir Zaman \nAge : 30")
# Out:
# Name : Tahir Zaman
# Age : 30

# %%
# Create two variables a = 5 and b = 3, then print their sum.
a = 5
b = 3
print("Sum:", a + b)
# Out:
# Sum: 8

# %%
# Store a float value in a variable and print its data type. 

Float_value = 10.5
print(type(Float_value))
# Out:
# <class 'float'>

# %%
# Take one number as input from the user and print it.

user_input = input("Entre Any thing")
print(user_input)
# Out:
# one botile Down > yo yo Honey singh

# %%
# Write a program that prints the result of 10 + 5 * 2.
print("The result of 10 + 5 * 2 =",10+5*2)
# Out:
# The result of 10 + 5 * 2 = 20

# %%
# Create a variable, assign a string to it, and print the value.
Variable = "String"
print(Variable)
# Out:
# String

# %%
# Take two integers as input and print their addition.
number1 = int(input("Entre Number 1"))
number2 =int(input("Entre Number 2"))
print("Addition of 2 number is :",number1 + number2)
# Out:
# Addition of 2 number is : 92

# %%
# Write a program that prints True or False for the expression 10 > 5. 
print(10 > 5)
# Out:
# True

# %%
# Store an integer in a variable, convert it to float, and print both values.
int_value = 7
float_value = float(int_value)
print("integer Value:", int_value)
print("Float Value:", float_value)
# Out:
# integer Value: 7
# Float Value: 7.0

# %%
# Print the result of 20 // 3 and explain what the operator does.
print("20 // 3 =", 20//3)

# The // operator performs floor division, which divides the number and rounds down to the nearest whole number.
# Out:
# 20 // 3 = 6

# %%
# Intermediate Level (Thinking with Code – 10 Questions)

# %%
# Take two numbers as input and print their sum, difference, product, and division.

num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

print("Sum", num1 + num2)
print("Difference", num1 - num2)
print("Product", num1 * num2)
print("Division", num1 / num2)
# Out:
# Sum 95
# Difference 5
# Product 2250
# Division 1.1111111111111112

# %%
# Write a program that checks whether a number is even or odd using operators
user_input = int(input("Enter a number: "))
if user_input % 2 == 0:
    print(f"{user_input} is Even")
else:
    print(f"{user_input} is Odd")
# Out:
# 55 is Odd
