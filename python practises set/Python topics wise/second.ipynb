# %%
# variable 
name = "Tahir"
print(name)
# Out:
# Tahir

# %%
X = 10 
Y = 20 
Z = X + Y
print(Z)
# Out:
# 30

# %%
a,b,c = 5,10,15
print(a)
print(b)
print(c)
# Out:
# 5
# 10
# 15

# %%
age = "i am 20 years old"
print(age)
# Out:
# i am 20 years old

# %%
city = "karachi"
city = "lahore"
print(city)
# Out:
# lahore

# %%
price = 200
discount = 50
final_price = price - discount
print(final_price)
# Out:
# 150

# %%
num1 = 23
num2 = 23.3
print(num1 + num2)
# Out:
# 46.3

# %%
PI = 3.14
print(PI)
# Out:
# 3.14

# %%
a,b = b,a 
print(a)
print(b)
# Out:
# 5
# 10

# %%
User_name = str(input("Enter your name: "))
print("Hello " + User_name)
# Out:
# Hello TAHIR

# %%
varibale1 = 10
varibale2 = "Hello"
varibale3 = 23.5
print(type(varibale1))
print(type(varibale2))
print(type(varibale3))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
fruit = ["Apple", "Banana", "Mango" , "Orange"]
print(fruit)
# Out:
# ['Apple', 'Banana', 'Mango', 'Orange']

# %%
tuple = (1,2,4, 2,1 )
print(tuple)
# Out:
# (1, 2, 4, 2, 1)

# %%
dict = {"name":"Tahir", "age":20, "city":"Karachi"}
print(dict)
# Out:
# {'name': 'Tahir', 'age': 20, 'city': 'Karachi'}

# %%
name = "Tahir"
print(len(name))
# Out:
# 5

# %%
a = "23"
print(a)
print(type(a))
# Out:
# 23
# <class 'str'>

# %%
a = "5"
print(a*10)
# Out:
# 5555555555

# %%
a = 10
b = 5 
c = a > b
print(c)
# Out:
# False

# %%
x = 15
y = 4
print(x + y )
print(x - y )
print(x * y )
print(x / y )
print(x // y )
print(x ** y)
# Out:
# 19
# 11
# 60
# 3.75
# 3
# 50625

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
sum = num1 * num2
print("The multiplication is:", sum)
# Out:
# The multiplication is: 1845

# %%
 a = 10
 b = 20
 c = a == b
 print(c)
# Out:
# False

# %%
if 50 > 30:
    print("50 is greater than 30")
else:
    print("30 is greater than 50")
# Out:
# 50 is greater than 30

# %%
print(10 > 5)
print(5 > 2)
# Out:
# True
# True

# %%
userinput = int(input("Entre something in numers :"))
print(userinput + 10)
# Out:
# 50

# %%
userinput = int(input("Entre something in numers :"))
print(userinput - 10)
# Out:
# 40
