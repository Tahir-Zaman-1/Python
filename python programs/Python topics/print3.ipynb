# %%
#today we learn print Function
print("Hello, World!")
print("Welcome to Python programming.")
print("This is a simple print function example.")
print("You can print numbers too:", 42)
print("You can print multiple items:", "Python", 3.8, True)
print("End of the print function demonstration.")
# Out:
# Hello, World!
# Welcome to Python programming.
# This is a simple print function example.
# You can print numbers too: 42
# You can print multiple items: Python 3.8 True
# End of the print function demonstration.
